# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('tmdb-movies.csv')

# %%
df_test
# Out:
#   <html lang="nl"><head><meta http-equiv="Content-Type" content="text/html; charset=ISO-8859-1"><title>Kennisgeving voor omleiding</title><style>body  \
# 0  document.getElementById(id).onclick=function()...
# 1  document.getElementById(id).onmousedown=functi...
#
#                                                  div  \
# 0                                                NaN
# 1  a=window&&window.encodeURIComponent?encodeURIC...
#
#                                 a{font-family:Roboto  HelveticaNeue  Arial  \
# 0                                                NaN            NaN    NaN
# 1  c="";b&&(c=a(b));(new Image).src="/url?sa=T&ur...            NaN    NaN
#
# ...

# %%
df.head(3)
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
# 2  262500  tt2908446   13.112507  110000000   295238201           Insurgent
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
#
#                                          homepage          director  \
# 0                   http://www.jurassicworld.com/   Colin Trevorrow
# 1                     http://www.madmaxmovie.com/     George Miller
# 2  http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
#
#                       tagline  ...  \
# 0           The park is open.  ...
# 1          What a Lovely Day.  ...
# 2  One Choice Can Destroy You  ...
#
# ...

# %%
##Remove the unnesessary rows
df.drop(['id', 'imdb_id', 'homepage', 'tagline', 'overview'], axis = 1, inplace = True)

# %%
df.head(1)
# Out:
#    popularity     budget     revenue  original_title  \
# 0   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast         director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
#
#                                             keywords  runtime  \
# 0  monster|dna|tyrannosaurus rex|velociraptor|island      124
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15        5562
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09

# %%
df.describe()
# Out:
#          popularity        budget       revenue       runtime    vote_count  \
# count  10866.000000  1.086600e+04  1.086600e+04  10866.000000  10866.000000
# mean       0.646441  1.462570e+07  3.982332e+07    102.070863    217.389748
# std        1.000185  3.091321e+07  1.170035e+08     31.381405    575.619058
# min        0.000065  0.000000e+00  0.000000e+00      0.000000     10.000000
# 25%        0.207583  0.000000e+00  0.000000e+00     90.000000     17.000000
# 50%        0.383856  0.000000e+00  0.000000e+00     99.000000     38.000000
# 75%        0.713817  1.500000e+07  2.400000e+07    111.000000    145.750000
# max       32.985763  4.250000e+08  2.781506e+09    900.000000   9767.000000
#
#        vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean       5.974922   2001.322658  1.755104e+07  5.136436e+07
# std        0.935142     12.812941  3.430616e+07  1.446325e+08
# ...

# %% [markdown]
# popularity : ok
# budget : 0 がある。。50%まで。。 "e"が入っているので直したほうがよいかな。\
# Revenue:同じく\
# runtie: 0 がある。
# vote, avarage: ok
# release year:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   popularity            10866 non-null  float64
#  1   budget                10866 non-null  int64
#  2   revenue               10866 non-null  int64
#  3   original_title        10866 non-null  object
#  4   cast                  10790 non-null  object
#  5   director              10822 non-null  object
#  6   keywords              9373 non-null   object
#  7   runtime               10866 non-null  int64
#  8   genres                10843 non-null  object
#  9   production_companies  9836 non-null   object
#  10  release_date          10866 non-null  object
#  11  vote_count            10866 non-null  int64
#  12  vote_average          10866 non-null  float64
#  13  release_year          10866 non-null  int64
#  14  budget_adj            10866 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# director                  44
# keywords                1493
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df[df.duplicated()]
# Out:
#       popularity    budget  revenue original_title  \
# 2090     0.59643  30000000   967000         TEKKEN
#
#                                                    cast          director  \
# 2090  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...  Dwight H. Little
#
#                                                keywords  runtime  \
# 2090  martial arts|dystopia|based on video game|mart...       92
#
#                                            genres    production_companies  \
# 2090  Crime|Drama|Action|Thriller|Science Fiction  Namco|Light Song Films
#
#      release_date  vote_count  vote_average  release_year  budget_adj  \
# 2090      3/20/10         110           5.0          2010  30000000.0
#
#       revenue_adj
# 2090     967000.0

# %%
type(df['release_date'][0])
# Out:
# str

# %% [markdown]
# Missing data:
# cast, keywords, genre, production
#
# Data type:
# seems ok

# %%
### delete duplicated
df.drop_duplicates(inplace = True)

# %%
#check if it is executed,
df.shape
# Out:
# (10865, 16)

# %%
##change the display for dicimal
df[['budget', 'revenue', 'budget_adj', 'revenue_adj']]= df[['budget', 'revenue', 'budget_adj', 'revenue_adj']].astype(float).round(5)

# %%
## check if it executed
df.head()
# Out:
#    popularity       budget       revenue                original_title  \
# 0   32.985763  150000000.0  1.513529e+09                Jurassic World
# 1   28.419936  150000000.0  3.784364e+08            Mad Max: Fury Road
# 2   13.112507  110000000.0  2.952382e+08                     Insurgent
# 3   11.173104  200000000.0  2.068178e+09  Star Wars: The Force Awakens
# 4    9.335014  190000000.0  1.506249e+09                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                                             keywords  runtime  \
# ...

# %%
##budget treat 0 as nan 
cols = ['budget', 'revenue', 'runtime', 'budget_adj', 'revenue_adj']
df[cols] = df[cols].replace({0:np.nan})

# %%
df.isna().sum()
# Out:
# popularity                 0
# budget                  5696
# revenue                 6016
# original_title             0
# cast                      76
# director                  44
# keywords                1493
# runtime                   31
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj              5696
# revenue_adj             6016
# dtype: int64

# %%
## change the display from e to normal dicimal
df
# Out:
#        popularity       budget       revenue                original_title  \
# 0       32.985763  150000000.0  1.513529e+09                Jurassic World
# 1       28.419936  150000000.0  3.784364e+08            Mad Max: Fury Road
# 2       13.112507  110000000.0  2.952382e+08                     Insurgent
# 3       11.173104  200000000.0  2.068178e+09  Star Wars: The Force Awakens
# 4        9.335014  190000000.0  1.506249e+09                     Furious 7
# ...           ...          ...           ...                           ...
# 10861    0.080598          NaN           NaN            The Endless Summer
# 10862    0.065543          NaN           NaN                    Grand Prix
# 10863    0.065141          NaN           NaN           Beregis Avtomobilya
# 10864    0.064317          NaN           NaN        What's Up, Tiger Lily?
# 10865    0.035919      19000.0           NaN      Manos: The Hands of Fate
#
# ...

# %% [markdown]
# ## Does year have any effect?

# %%
fig, ax = plt.subplots(figsize=(20,8))
ax = sns.countplot(data = df, x = 'release_year', color = 'skyblue')
ax.set_xlabel('Release Year', fontsize = 15)
ax.set_ylabel('The Number of Films', fontsize = 15)
ax.set_title('The Number of Films per Release Year', fontsize = 20)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90);

# %%
df.groupby('release_year').mean().vote_average.plot(kind='bar', figsize = (20,8), color = 'skyblue')
plt.xlabel('Release Year', fontsize = 15)
plt.ylabel('Average vote', fontsize = 15)
plt.title('The average vote per Release Year', fontsize = 20);

# %%
df.groupby('release_year').sum().vote_count.plot(kind='bar', figsize = (20,8), color = 'skyblue')
plt.xlabel('Release Year', fontsize = 15)
plt.ylabel('The Number of vote', fontsize = 15)
plt.title('The Number of vote per Release Year', fontsize = 20);

# %%
## there is more film reistered and more vote in recent yeares, but the avg_ rate is lower.

# %%
## NOW we look into the budget

# %%
df.hist(figsize = (10,10));

# %%
df[df.budget != np.nan].hist(figsize = (10,10));

# %%
# distribution seems not significantly different

# %%
## drop 0 
df_budget = df.dropna()

# %%
df_budget.describe()
# Out:
#         popularity        budget       revenue      runtime   vote_count  \
# count  3677.000000  3.677000e+03  3.677000e+03  3677.000000  3677.000000
# mean      1.226051  3.811465e+07  1.114405e+08   109.561327   547.702203
# std       1.498897  4.267577e+07  1.793625e+08    19.855075   894.954704
# min       0.010335  1.000000e+00  2.000000e+00    26.000000    10.000000
# 25%       0.481276  1.000000e+07  1.489942e+07    96.000000    78.000000
# 50%       0.830597  2.500000e+07  4.806344e+07   106.000000   219.000000
# 75%       1.411147  5.000000e+07  1.298324e+08   120.000000   596.000000
# max      32.985763  4.250000e+08  2.781506e+09   338.000000  9767.000000
#
#        vote_average  release_year    budget_adj   revenue_adj
# count   3677.000000   3677.000000  3.677000e+03  3.677000e+03
# mean       6.182758   2001.091923  4.538793e+07  1.420888e+08
# std        0.789610     11.380391  4.519195e+07  2.195158e+08
# min        2.200000   1960.000000  9.694000e-01  2.861930e+00
# ...

# %%
## you stil see budget ### you need to think what to do or it is usuful to look into it.

# %%
df[df.budget < 1000].hist(figsize = (10,10));

# %%
df_budget[df.budget > 10000].plot(kind = 'scatter', x = 'budget', y = 'vote_average', figsize = (20,10))
plt.xlabel('Budget', fontsize = 18)
plt.ylabel('Vote Average', fontsize = 18)
plt.title('Vote Average vs Budget', fontsize = 20);
plt.xlim(0)
plt.ylim(0)
# Out:
# C:\Users\Kaori\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# (0.0, 8.71)

# %%
## high budget doesnt mean higher rate. altough it will go closer to the mean

# %%
## runtime?

# %%
df_budget.plot(kind = 'scatter', x = 'runtime', y = 'vote_average', figsize = (20,10))
plt.xlabel('Runtime', fontsize = 18)
plt.ylabel('Vote Average', fontsize = 18)
plt.title('Vote Average vs Runtime', fontsize = 20);

# %%
## check if the cast is affecting
df_cast = df.copy()

# %%
df_cast = df_cast.drop('cast', axis=1).join(df_cast['cast'].str.split('|', expand = True).stack().rename('cast').reset_index(drop = True))

# %%
df_cast2 = df_cast.groupby('cast').count().sort_values(by = 'original_title', ascending = False)

# %%
df_cast2.head()
# Out:
#                    popularity  budget  revenue  original_title  director  \
# cast
# Justin Long                14       6        7              14        14
# Liam Neeson                14       7        8              14        14
# James Franco               12       5        7              12        12
# Samuel L. Jackson          12       4        4              12        12
# Nicolas Cage               12       7        9              12        12
#
#                    keywords  runtime  genres  production_companies  \
# cast
# Justin Long              13       14      14                    12
# Liam Neeson              13       14      14                    12
# James Franco             10       12      12                    12
# Samuel L. Jackson        10       12      12                    10
# Nicolas Cage             12       12      12                    11
#
#                    release_date  vote_count  vote_average  release_year  \
# cast
# ...

# %%
df_cast.head(1)
# Out:
#    popularity       budget       revenue  original_title         director  \
# 0   32.985763  150000000.0  1.513529e+09  Jurassic World  Colin Trevorrow
#
#                                             keywords  runtime  \
# 0  monster|dna|tyrannosaurus rex|velociraptor|island    124.0
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15        5562
#
#    vote_average  release_year    budget_adj   revenue_adj         cast
# 0           6.5          2015  1.379999e+08  1.392446e+09  Chris Pratt

# %%
plt.figure(figsize=(20,5))
sns.boxplot(df_cast2.index, df_cast2.vote_average0(), color = 'orange');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-70b1daa66fbf> in <module>
#       1 plt.figure(figsize=(20,5))
# ----> 2 sns.boxplot(df_cast2.index, df_cast2.vote_average0(), color = 'orange');
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5128             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5129                 return self[name]
# -> 5130             return object.__getattribute__(self, name)
#    5131
#    5132     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'vote_average0'

# %%
# Make a function to make one data per column by expanding rows
def expand(df, col):
    if type(col) != str:
        raise TypeError('col must be string')
    else:
        return df.drop(col, axis=1).join(df[col].str.split('|', expand = True).stack().rename(col).reset_index(drop = True))

# %%
df_cast = expand(df, 'production_companies')

# %%
df_cast.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# ...

# %%
df_cast_features =
